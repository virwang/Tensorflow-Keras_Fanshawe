# %%
# INFO-6146 – In-class Activity #1 (10 Marks)
# Dataset: California Housing
# Objective: Assess understanding of model architecture, loss functions, training process and evaluation.

import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

np.random.seed(42)
tf.random.set_seed(42)

# SECTION 1 – LOAD DATA

data = fetch_california_housing()

X = data.data
y = data.target

print("Feature shape:", X.shape)
print("Target shape:", y.shape)


# SECTION 2 – TRAIN TEST SPLIT (FILL IN THE BLANKS)
# QUESTION 1 (1 mark):Choose an appropriate test_size and explain in comments why you selected it.

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=___________, random_state=42
)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

print("Training samples:", X_train.shape[0])
print("Test samples:", X_test.shape[0])


# SECTION 3 – BUILD MODEL (FILL IN THE BLANKS)
# QUESTION 2(1 mark): Build a regression model with One hidden layer with appropriate number of neurons and activation function
# Explain your choices in comments.

model = __________([
    __________(___, activation="__________", input_shape=(X_train.shape[1],)),
    __________(1)
])

model.summary()

# SECTION 4 – COMPILE MODEL (FILL IN THE BLANKS)
# QUESTION 3(1 mark): Define the optimizer, loss function and metric
# Explain why you chose them in comments.

model.compile(
    optimizer="__________",
    loss="__________",
    metrics=["__________"]
)


# SECTION 5 – TRAIN MODEL (FILL IN THE BLANKS)
# QUESTION 4(1 mark): Select the number epochs, batch_size and validation_split
# Explain why you picked those values in comments.

history = model.fit(
    X_train,
    y_train,
    validation_split=__________,
    epochs=__________,
    batch_size=__________,
    verbose=0
)

print("Training complete.")


# SECTION 6 – PLOT LOSS CURVES (FILL IN THE BLANKS)
# QUESTION 5(1 mark): Plot training loss and validation loss.
# Comment on whether the model is overfitting or underfitting?

plt.plot(history.history["__________"], label="Training Loss")
plt.plot(history.history["__________"], label="Validation Loss")

plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.title("Training vs Validation Loss")
plt.show()


# SECTION 7 – MODEL EVALUATION (FILL IN THE BLANKS)
# QUESTION 6(2 marks): Evaluate the model on test data and explain what the results indicate.

test_loss, test_metric = model.evaluate(__________, __________)

print("Test Loss:", test_loss)
print("Test Metric:", test_metric)


# SECTION 8 – MODEL IMPROVEMENT
# QUESTION 7 (2 marks): Add another hidden layer (64 neurons).
# Keep the same activation function as used previously.
# Compare performance and explain the difference.
# ============================================================

model_2 = Sequential([
    Dense(64, activation="__________", input_shape=(X_train.shape[1],)),
    Dense(32, activation="__________"),
    Dense(1)
])

model_2.compile(
    optimizer="adam",
    loss="mse"
)

history_2 = model_2.fit(
    X_train,
    y_train,
    validation_split=0.2,
    epochs=50,
    verbose=0
)

print("Model 2 trained.")

# SECTION 9 – ACTIVATION FUNCTION CHANGE
# QUESTION 8(1 mark): Replace the activation function with a different one.
# Observe training behaviour and explain the difference.

model_3 = Sequential([
    Dense(32, activation="__________", input_shape=(X_train.shape[1],)),
    Dense(1)
])

model_3.compile(
    optimizer="adam",
    loss="mse"
)

history_3 = model_3.fit(
    X_train,
    y_train,
    validation_split=0.2,
    epochs=50,
    verbose=0
)

print("Model 3 trained.")

# Add your reflections as comments at each stage in the code.

# %%
pip install scikit-learn tensorflow matplotlib
# Out:
# Requirement already satisfied: scikit-learn in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (1.7.2)
# Collecting tensorflow
#   Downloading tensorflow-2.20.0-cp310-cp310-win_amd64.whl.metadata (4.6 kB)
# Requirement already satisfied: matplotlib in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (3.10.6)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from scikit-learn) (3.5.0)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Using cached gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from tensorflow) (25.0)
# Collecting protobuf>=5.28.0 (from tensorflow)
#   Downloading protobuf-6.33.5-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from tensorflow) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Using cached termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from tensorflow) (4.15.0)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-2.1.1-cp310-cp310-win_amd64.whl.metadata (7.6 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.78.1-cp310-cp310-win_amd64.whl.metadata (3.9 kB)
# Collecting tensorboard~=2.20.0 (from tensorflow)
#   Using cached tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.10.0 (from tensorflow)
#   Downloading keras-3.12.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting h5py>=3.11.0 (from tensorflow)
#   Downloading h5py-3.15.1-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.4-cp310-cp310-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Collecting markdown>=2.6.8 (from tensorboard~=2.20.0->tensorflow)
#   Downloading markdown-3.10.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: pillow in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.20.0->tensorflow)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.20.0->tensorflow)
#   Downloading werkzeug-3.1.6-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Collecting rich (from keras>=3.10.0->tensorflow)
#   Downloading rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.10.0->tensorflow)
#   Using cached namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.10.0->tensorflow)
#   Downloading optree-0.19.0-cp310-cp310-win_amd64.whl.metadata (35 kB)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.10.0->tensorflow)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\virginia\miniconda3\envs\secmlf25\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.20.0-cp310-cp310-win_amd64.whl (331.7 MB)
#    ---------------------------------------- 0.0/331.7 MB ? eta -:--:--
#    ---------------------------------------- 0.5/331.7 MB ? eta -:--:--
#    ---------------------------------------- 1.8/331.7 MB 5.9 MB/s eta 0:00:56
#    ---------------------------------------- 2.9/331.7 MB 5.6 MB/s eta 0:00:59
#     --------------------------------------- 4.2/331.7 MB 5.7 MB/s eta 0:00:58
#     --------------------------------------- 5.0/331.7 MB 5.7 MB/s eta 0:00:58
#     --------------------------------------- 5.8/331.7 MB 5.0 MB/s eta 0:01:06
#     --------------------------------------- 6.8/331.7 MB 5.1 MB/s eta 0:01:05
#    - -------------------------------------- 8.4/331.7 MB 5.4 MB/s eta 0:01:01
#    - -------------------------------------- 10.7/331.7 MB 6.0 MB/s eta 0:00:54
#    - -------------------------------------- 14.4/331.7 MB 7.2 MB/s eta 0:00:45
#    -- ------------------------------------- 17.6/331.7 MB 7.9 MB/s eta 0:00:40
#    -- ------------------------------------- 20.4/331.7 MB 8.4 MB/s eta 0:00:38
#    -- ------------------------------------- 22.5/331.7 MB 8.6 MB/s eta 0:00:36
MB 9.1 MB/s eta 0:00:02
#    -------------------------------------- - 319.0/331.7 MB 9.1 MB/s eta 0:00:02
#    -------------------------------------- - 320.6/331.7 MB 9.1 MB/s eta 0:00:02
#    -------------------------------------- - 322.4/331.7 MB 9.1 MB/s eta 0:00:02
#    ---------------------------------------  324.3/331.7 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------  326.4/331.7 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------  328.5/331.7 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------  330.3/331.7 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------  331.6/331.7 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------  331.6/331.7 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------  331.6/331.7 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------  331.6/331.7 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------  331.6/331.7 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------  331.6/331.7 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------  331.6/331.7 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 331.7/331.7 MB 8.7 MB/s  0:00:38
# Downloading grpcio-1.78.1-cp310-cp310-win_amd64.whl (4.8 MB)
#    ---------------------------------------- 0.0/4.8 MB ? eta -:--:--
#    ------------- -------------------------- 1.6/4.8 MB 8.3 MB/s eta 0:00:01
#    ------------------------------ --------- 3.7/4.8 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 4.8/4.8 MB 8.5 MB/s  0:00:00
# Downloading ml_dtypes-0.5.4-cp310-cp310-win_amd64.whl (210 kB)
# Using cached tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Using cached gast-0.7.0-py3-none-any.whl (22 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading h5py-3.15.1-cp310-cp310-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    -------------- ------------------------- 1.0/2.9 MB 5.6 MB/s eta 0:00:01
#    ------------------------------------ --- 2.6/2.9 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 7.3 MB/s  0:00:00
# Downloading keras-3.12.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 7.8 MB/s  0:00:00
# Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Downloading markdown-3.10.2-py3-none-any.whl (108 kB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading protobuf-6.33.5-cp310-abi3-win_amd64.whl (437 kB)
# Using cached termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading werkzeug-3.1.6-py3-none-any.whl (225 kB)
# Downloading wrapt-2.1.1-cp310-cp310-win_amd64.whl (60 kB)
# Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.19.0-cp310-cp310-win_amd64.whl (321 kB)
# Downloading rich-14.3.3-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorboard-data-server, protobuf, optree, opt_einsum, ml_dtypes, mdurl, markdown, h5py, grpcio, google_pasta, gast, astunparse, absl-py, tensorboard, markdown-it-py, rich, keras, tensorflow
#
#    - --------------------------------------  1/24 [libclang]
#    - --------------------------------------  1/24 [libclang]
#    - --------------------------------------  1/24 [libclang]
#    - --------------------------------------  1/24 [libclang]
#    - --------------------------------------  1/24 [libclang]
#    - --------------------------------------  1/24 [libclang]
#    - --------------------------------------  1/24 [libclang]
#    - --------------------------------------  1/24 [libclang]
#    --- ------------------------------------  2/24 [flatbuffers]
#    ----- ----------------------------------  3/24 [wrapt]
#    ------ ---------------------------------  4/24 [werkzeug]
#    ------ ---------------------------------  4/24 [werkzeug]
#    ------ ---------------------------------  4/24 [werkzeug]
#    ------ ---------------------------------  4/24 [werkzeug]
#    ------ ---------------------------------  4/24 [werkzeug]
#    ------ ---------------------------------  4/24 [werkzeug]
#    ------ ---------------------------------  4/24 [werkzeug]
#    -------- -------------------------------  5/24 [termcolor]
#    ----------- ----------------------------  7/24 [protobuf]
#    ----------- ----------------------------  7/24 [protobuf]
#    ----------- ----------------------------  7/24 [protobuf]
#    ----------- ----------------------------  7/24 [protobuf]
#    ----------- ----------------------------  7/24 [protobuf]
#    ----------- ----------------------------  7/24 [protobuf]
#    ----------- ----------------------------  7/24 [protobuf]
#    ------------- --------------------------  8/24 [optree]
#    ------------- --------------------------  8/24 [optree]
#    --------------- ------------------------  9/24 [opt_einsum]
#    --------------- ------------------------  9/24 [opt_einsum]
#    ---------------- ----------------------- 10/24 [ml_dtypes]
#    ------------------ --------------------- 11/24 [mdurl]
#    -------------------- ------------------- 12/24 [markdown]
#    -------------------- ------------------- 12/24 [markdown]
#    -------------------- ------------------- 12/24 [markdown]
#    -------------------- ------------------- 12/24 [markdown]
#    --------------------- ------------------ 13/24 [h5py]
#    --------------------- ------------------ 13/24 [h5py]
#    --------------------- ------------------ 13/24 [h5py]
#    --------------------- ------------------ 13/24 [h5py]
#    --------------------- ------------------ 13/24 [h5py]
#    --------------------- ------------------ 13/24 [h5py]
#    --------------------- ------------------ 13/24 [h5py]
#    --------------------- ------------------ 13/24 [h5py]
#    ----------------------- ---------------- 14/24 [grpcio]
#    ----------------------- ---------------- 14/24 [grpcio]
#    ----------------------- ---------------- 14/24 [grpcio]
#    ----------------------- ---------------- 14/24 [grpcio]
#    ----------------------- ---------------- 14/24 [grpcio]
#    ----------------------- ---------------- 14/24 [grpcio]
#    ----------------------- ---------------- 14/24 [grpcio]
#    ------------------------- -------------- 15/24 [google_pasta]
#    ------------------------- -------------- 15/24 [google_pasta]
#    -------------------------- ------------- 16/24 [gast]
#    ---------------------------- ----------- 17/24 [astunparse]
#    ------------------------------ --------- 18/24 [absl-py]
#    ------------------------------ --------- 18/24 [absl-py]
#    ------------------------------ --------- 18/24 [absl-py]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    ------------------------------- -------- 19/24 [tensorboard]
#    --------------------------------- ------ 20/24 [markdown-it-py]
#    --------------------------------- ------ 20/24 [markdown-it-py]
#    --------------------------------- ------ 20/24 [markdown-it-py]
#    --------------------------------- ------ 20/24 [markdown-it-py]
#    --------------------------------- ------ 20/24 [markdown-it-py]
#    --------------------------------- ------ 20/24 [markdown-it-py]
#    ----------------------------------- ---- 21/24 [rich]
#    ----------------------------------- ---- 21/24 [rich]
#    ----------------------------------- ---- 21/24 [rich]
#    ----------------------------------- ---- 21/24 [rich]
#    ----------------------------------- ---- 21/24 [rich]
#    ----------------------------------- ---- 21/24 [rich]
#    ----------------------------------- ---- 21/24 [rich]
#    ----------------------------------- ---- 21/24 [rich]
#    ----------------------------------- ---- 21/24 [rich]
#    ----------------------------------- ---- 21/24 [rich]
#    ----------------------------------- ---- 21/24 [rich]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    ------------------------------------ --- 22/24 [keras]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]Note: you may need to restart the kernel to use updated packages.
#
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    -------------------------------------- - 23/24 [tensorflow]
#    ---------------------------------------- 24/24 [tensorflow]
#
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 flatbuffers-25.12.19 gast-0.7.0 google_pasta-0.2.0 grpcio-1.78.1 h5py-3.15.1 keras-3.12.1 libclang-18.1.1 markdown-3.10.2 markdown-it-py-4.0.0 mdurl-0.1.2 ml_dtypes-0.5.4 namex-0.1.0 opt_einsum-3.4.0 optree-0.19.0 protobuf-6.33.5 rich-14.3.3 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 termcolor-3.3.0 werkzeug-3.1.6 wrapt-2.1.1
