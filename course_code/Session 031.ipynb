# %%
import tensorflow as tf
import numpy as np
# Synthetic dataset: points above/below line y = x
X = np.random.rand(1000, 2)
y = (X[:, 0] + X[:, 1] > 1).astype(int) # label 1 if sum > 1
# Build a simple classifier
model = tf.keras.Sequential([
tf.keras.layers.Dense(8, activation="relu", input_shape=(2,)),
tf.keras.layers.Dense(1, activation="sigmoid")
])
# Compile model
model.compile(optimizer="adam",
loss="binary_crossentropy",
metrics=["accuracy"])
# Train model
# Evaluate model
history = model.fit(X, y, epochs=5, batch_size=32, validation_split=0.2)
loss, acc = model.evaluate(X, y)
print("Accuracy:", acc)
# Expected output: Accuracy ~0.90
# Out:
# Epoch 1/5
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4968 - loss: 0.7124 - val_accuracy: 0.4650 - val_loss: 0.7089
# Epoch 2/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4610 - loss: 0.7073 - val_accuracy: 0.3900 - val_loss: 0.7020
# Epoch 3/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4441 - loss: 0.6999 - val_accuracy: 0.4600 - val_loss: 0.6959
# Epoch 4/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4768 - loss: 0.6957 - val_accuracy: 0.5750 - val_loss: 0.6902
# Epoch 5/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5930 - loss: 0.6899 - val_accuracy: 0.6500 - val_loss: 0.6850
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6305 - loss: 0.6863
# Accuracy: 0.6439999938011169
